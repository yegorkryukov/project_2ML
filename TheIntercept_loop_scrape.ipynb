# %%
# dependencies
import pymongo as pm
import urllib
from scrape import Scrape as sc
from pprint import pprint
from bs4 import BeautifulSoup as bs
import re
import time

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pm.MongoClient(conn)

# %%
# define db and collections
db = client.scrape_db

# this collection will store all the HTML pages
htmlCollection = db.HTML_pages

# %%
# declare top-level url and domain
# startURL = 'https://billypenn.com/'
# domain = 'billypenn.com'

startURL = 'https://theintercept.com/'
domain = 'theintercept.com'

# establish necessary data structures
done_urls = set()
external_urls = []
urls = set()
pagelinks = set()

# seed with top-level url of website
urls.add(startURL)

# %%
# counter for limiting functions
ctr = 0

# continue to loop through urls until we have scraped all valid
# needed a while loop so we can modify size of urls through process
while (len(urls) > 0) and ctr < 6:    #(len(done_urls) < 200):
    
    # timer for performance across url loops
    forStart = time.time()
    
    # go through every url that has not been scraped yet
    for url in urls:
        print("URL in for loop: ", url)
        
        # timer for performance
        start = time.time()
        
        # governor to avoid being banned/blocked
        time.sleep(5)   # time governor
        
        # check for email and run all other links through scrape
        html = sc.scrapeHTML(url)
        
        # end timer for performance and print status
        end = time.time()
        print(f'Elapsed time: {end - start}')
        
        # validate html and then add to the pagelinks all the links that were scraped
        if html: 
            #print(f'Html scraped: {html[:50]}')
            data = {
                "url": url, 
                "html": html, 
                }

            # insert dict into db document
            htmlCollection.insert_one(data)
            
            # record url in "done" collection
            done_urls.add(url)
            
            pagelinks = pagelinks.union(sc.scrapeURL(html, url))
            print(f'Extracted links: {len(pagelinks)}')
        else:
            print(f'Main Loop: HTML not extracted')
        
        ####################################################
        # TODO: update done_urls, external and urls to CSV #
        ####################################################
        
    # end timer of for loop
    forEnd = time.time()
    
    # print status for testing
    print()
    print(f'Number of Urls: {len(urls)}')
    print(f'Process Time: {forEnd -forStart}')
    print('--------------------------------------------------------------')
        
        
    
    # add links from page to urls set outside of for loop
    if html:
        for link in pagelinks:
            if domain in link:
                urls.add(link)
                # print(f"Link in pagelinks: {link}")
            else:
                external_urls.append(link)
    
    # remove done_urls from todo urls and increment counter
    urls -= done_urls
    ctr += 1
    
    # print status for testing
    print("done_urls: ", len(done_urls))
    print("(urls - done_urls): ", len(urls))
    print("LOOP counter: ", ctr)
    print("--------------------")
# Out:
# URL in for loop:  https://theintercept.com/
# Elapsed time: 5.925551414489746
# Extracted links: 38
#
# Number of Urls: 1
# Process Time: 6.025622367858887
# --------------------------------------------------------------
# done_urls:  1
# (urls - done_urls):  30
# LOOP counter:  1
# --------------------
# URL in for loop:  https://theintercept.com/series/
# Elapsed time: 5.513433218002319
# Extracted links: 43
# URL in for loop:  https://theintercept.com/about/
# Elapsed time: 5.475137948989868
# Extracted links: 164
# URL in for loop:  https://theintercept.com/source/
# Elapsed time: 5.351520538330078
# Extracted links: 176
# URL in for loop:  https://theintercept.com/documents/
# Elapsed time: 5.333866357803345
# Extracted links: 188
# URL in for loop:  https://theintercept.com/2018/06/14/nypd-gang-database-city-council-dermot-shea/
# Elapsed time: 5.393671989440918
# Extracted links: 205
# URL in for loop:  https://theintercept.com/terms-use/
# Elapsed time: 5.478217124938965
# Extracted links: 217
# URL in for loop:  https://theintercept.com/feeds/
# Elapsed time: 5.373952627182007
# Extracted links: 235
# URL in for loop:  https://theintercept.com/#top-stories
# Elapsed time: 5.756240129470825
# Extracted links: 235
# URL in for loop:  https://theintercept.com/2018/06/15/domestic-violence-asylum-jeff-sessions/
# Elapsed time: 5.42358136177063
# Extracted links: 251
# URL in for loop:  https://theintercept.com/newsletter/
# Elapsed time: 5.342800140380859
# Extracted links: 252
# URL in for loop:  https://theintercept.com/#recently
# Elapsed time: 5.8694071769714355
# Extracted links: 252
# URL in for loop:  https://theintercept.com/donate/?campaign=70146000000HLS1AAO
# Elapsed time: 5.4116246700286865
# Extracted links: 259
# URL in for loop:  https://theintercept.com/podcasts/?campaign=homepage-podcast
# Elapsed time: 5.454468727111816
# Extracted links: 284
# URL in for loop:  https://theintercept.com/2018/06/15/will-the-u-s-ever-give-up-its-nukes/
# Elapsed time: 5.364870548248291
# Extracted links: 296
# URL in for loop:  https://theintercept.com/donate/?campaign=70146000000YxhuAAC
# Elapsed time: 5.368979215621948
# Extracted links: 297
# URL in for loop:  https://theintercept.com/2018/06/15/cve-grants-muslim-surveillance-brennan-center/
# Elapsed time: 5.4246299266815186
# Extracted links: 314
# URL in for loop:  https://theintercept.com/2018/06/14/bay-area-muslim-leader-has-her-award-rescinded-by-inter-faith-group-after-pro-israel-activists-objected/
# Elapsed time: 5.421067237854004
# Extracted links: 326
# URL in for loop:  https://theintercept.com/?menu=1
# Elapsed time: 5.8357813358306885
# Extracted links: 329
# URL in for loop:  https://theintercept.com/sitemap_index.xml
# Elapsed time: 5.375138521194458
# Extracted links: 329
# URL in for loop:  https://theintercept.com/features/
# Elapsed time: 5.666476488113403
# Extracted links: 338
# URL in for loop:  https://theintercept.com/2018/06/13/bipartisan-war-party-panics-as-kim-meets-trump/?campaign=homepage-podcast-intercepted
# Elapsed time: 5.641286134719849
# Extracted links: 349
# URL in for loop:  https://theintercept.com/greenwald/
# Elapsed time: 5.417957305908203
# Extracted links: 350
# URL in for loop:  https://theintercept.com/2018/06/15/prosecutors-misconduct-criminal-justice-reform-texas/
# Elapsed time: 5.426922798156738
# Extracted links: 364
# URL in for loop:  https://theintercept.com/privacy-policy/
# Elapsed time: 5.411653280258179
# Extracted links: 372
# URL in for loop:  https://theintercept.com/brasil/
# Elapsed time: 5.548785924911499
# Extracted links: 385
# URL in for loop:  https://theintercept.com/podcasts/
# Elapsed time: 5.477632522583008
# Extracted links: 388
# URL in for loop:  https://theintercept.com/policies/
# Elapsed time: 5.355478763580322
# Extracted links: 396
# URL in for loop:  https://theintercept.com/puerto-rico/
# Elapsed time: 5.356809139251709
# Extracted links: 409
# URL in for loop:  https://theintercept.com/2018/06/15/will-the-u-s-ever-give-up-its-nukes/?campaign=homepage-podcast-deconstructed
# Elapsed time: 5.404778003692627
# Extracted links: 410
# URL in for loop:  https://theintercept.com/#greenwald
# Elapsed time: 5.859476089477539
# Extracted links: 410
#
# Number of Urls: 30
# Process Time: 165.63297629356384
# --------------------------------------------------------------
# done_urls:  31
# (urls - done_urls):  251
# LOOP counter:  2
# --------------------
# URL in for loop:  https://theintercept.com/2018/06/10/guantanamo-bay-debi-cornwall-camp-america/
# Elapsed time: 5.497705936431885
# Extracted links: 448
# URL in for loop:  https://twitter.com/intent/tweet?text=Privacy%20Policy%20https%3A%2F%2Ftheintercept.com%2Fprivacy-policy%2F
# Elapsed time: 5.2462873458862305
# Extracted links: 452
# URL in for loop:  https://theintercept.com/staff/margueritenutter/
# Elapsed time: 7.1059510707855225
# Extracted links: 455
# URL in for loop:  mailto:alleen.brown@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:alleen.brown@theintercept.com'
# Elapsed time: 5.005657911300659
# Main Loop: HTML not extracted
# URL in for loop:  mailto:philipp.hubert@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:philipp.hubert@theintercept.com'
# Elapsed time: 5.005789756774902
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/zaidjilani/
# Elapsed time: 7.14644193649292
# Extracted links: 463
# URL in for loop:  https://theintercept.com/staff/matthewcole/
# Elapsed time: 7.329935073852539
# Extracted links: 473
# URL in for loop:  https://theintercept.com/staff/murtaza-hussain/feed/?rss
# Elapsed time: 5.665830373764038
# Extracted links: 668
# URL in for loop:  https://theintercept.com/2018/06/13/bipartisan-war-party-panics-as-kim-meets-trump/
# Elapsed time: 5.6326048374176025
# Extracted links: 669
# URL in for loop:  https://theintercept.com/document/2018/05/25/carta-da-confederacao-nacional-dos-transportadores-autonomos/
# Elapsed time: 5.397487640380859
# Extracted links: 670
# URL in for loop:  https://theintercept.com/staff/andrew-fishman/
# Elapsed time: 6.138794422149658
# Extracted links: 678
# URL in for loop:  mailto:soohee.cho@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:soohee.cho@theintercept.com'
# Elapsed time: 5.002329349517822
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2017/05/01/cybersecurity-for-the-people-how-to-keep-your-chats-truly-private-with-signal/
# Elapsed time: 5.480416297912598
# Extracted links: 705
# URL in for loop:  https://theintercept.com/2018/06/14/bay-area-muslim-leader-has-her-award-rescinded-by-inter-faith-group-after-pro-israel-activists-objected?menu=1
# Elapsed time: 5.468323469161987
# Extracted links: 706
# URL in for loop:  https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftheintercept.com%2Fterms-use%2F
# Elapsed time: 6.0442070960998535
# Extracted links: 714
# URL in for loop:  mailto:ryan.gallagher@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:ryan.gallagher@theintercept.com'
# Elapsed time: 5.002596378326416
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/margotwilliams/
# Elapsed time: 8.349853277206421
# Extracted links: 722
# URL in for loop:  https://theintercept.com/2018/05/30/white-fear-as-the-gop-veers-toward-fascism-establishment-democrats-face-a-grassroots-insurgency/
# Elapsed time: 6.403213977813721
# Extracted links: 728
# URL in for loop:  mailto:alice.speri@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:alice.speri@theintercept.com'
# Elapsed time: 5.006797552108765
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/donor-faq/
# Elapsed time: 6.032822370529175
# Extracted links: 741
# URL in for loop:  https://theintercept.com/2017/05/23/to-deepen-our-investigative-journalism-were-asking-for-reader-support/
# Elapsed time: 6.127825975418091
# Extracted links: 749
# URL in for loop:  https://theintercept.com/donor-roll/
# Elapsed time: 5.983006238937378
# Extracted links: 754
# URL in for loop:  https://twitter.com/intent/tweet?text=Terms%20of%20Use%20https%3A%2F%2Ftheintercept.com%2Fterms-use%2F
# Elapsed time: 5.285603046417236
# Extracted links: 754
# URL in for loop:  https://theintercept.com/podcasts/deconstructed/faq
# Elapsed time: 5.529842853546143
# Extracted links: 756
# URL in for loop:  https://theintercept.com/podcasts/?campaign=homepage-podcast#deconstructed
# Elapsed time: 5.42451548576355
# Extracted links: 756
# URL in for loop:  https://theintercept.com/staff/
# Elapsed time: 5.550512790679932
# Extracted links: 760
# URL in for loop:  mailto:peter.maass@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:peter.maass@theintercept.com'
# Elapsed time: 5.005914211273193
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/charlottegreensit/
# Elapsed time: 7.199651002883911
# Extracted links: 763
# URL in for loop:  https://theintercept.com/feed/?rss
# Elapsed time: 5.697808265686035
# Extracted links: 1012
# URL in for loop:  mailto:jack.disidoro@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:jack.disidoro@theintercept.com'
# Elapsed time: 5.005072355270386
# Main Loop: HTML not extracted
# URL in for loop:  https://twitter.com/intent/tweet?text=Editorial%20Policies%20and%20Procedures%20https%3A%2F%2Ftheintercept.com%2Fpolicies%2F
# Elapsed time: 5.2843687534332275
# Extracted links: 1012
# URL in for loop:  https://theintercept.com/2018/06/15/cve-grants-muslim-surveillance-brennan-center/?comments=1#comments
# Elapsed time: 6.302151679992676
# Extracted links: 1013
# URL in for loop:  https://theintercept.com/brasil/greenwald/
# Elapsed time: 5.534563302993774
# Extracted links: 1021
# URL in for loop:  https://theintercept.com/feed/?post_type=document
# Elapsed time: 5.3437371253967285
# Extracted links: 1031
# URL in for loop:  https://twitter.com/intent/tweet?text=Subscribe%20to%20RSS%20feeds%20https%3A%2F%2Ftheintercept.com%2Ffeeds%2F
# Elapsed time: 5.2865941524505615
# Extracted links: 1031
# URL in for loop:  https://theintercept.com/2018/02/14/alt-right-campus-free-speech-adl-splc/
# Elapsed time: 5.41923189163208
# Extracted links: 1052
# URL in for loop:  https://theintercept.com/2017/10/24/why-we-reinstalled-securedrop/
# Elapsed time: 5.4257237911224365
# Extracted links: 1061
# URL in for loop:  https://theintercept.com/2018/06/12/fotos-funcionarios-itaipu-incendio-indigenas/
# Elapsed time: 5.3993000984191895
# Extracted links: 1070
# URL in for loop:  https://theintercept.com/2016/05/14/orange-county-scandal-jailhouse-informants/
# Elapsed time: 5.558931589126587
# Extracted links: 1085
# URL in for loop:  mailto:charlotte.greensit@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:charlotte.greensit@theintercept.com'
# Elapsed time: 5.005847930908203
# Main Loop: HTML not extracted
# URL in for loop:  mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fprivacy-policy%2F
# ScrapeHTML: No connection adapters were found for 'mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fprivacy-policy%2F'
# Elapsed time: 5.0059356689453125
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/aidachavez/
# Elapsed time: 8.23036789894104
# Extracted links: 1092
# URL in for loop:  https://theintercept.com/2018/06/15/will-the-u-s-ever-give-up-its-nukes?menu=1
# Elapsed time: 5.8658952713012695
# Extracted links: 1093
# URL in for loop:  https://theintercept.com/2018/05/31/trump-russia-mueller-investigation-obstruction-of-justice/
# Elapsed time: 5.683101415634155
# Extracted links: 1119
# URL in for loop:  https://theintercept.com/2018/06/15/domestic-violence-asylum-jeff-sessions?menu=1
# Elapsed time: 5.871980428695679
# Extracted links: 1120
# URL in for loop:  https://theintercept.com/donor-privacy/
# Elapsed time: 6.013555526733398
# Extracted links: 1131
# URL in for loop:  https://theintercept.com/surveillance-catalogue/
# Elapsed time: 5.492959022521973
# Extracted links: 1196
# URL in for loop:  https://theintercept.com/?menu=1#top-stories
# Elapsed time: 6.038069725036621
# Extracted links: 1196
# URL in for loop:  https://theintercept.com/podcasts/deconstructed
# Elapsed time: 5.504604339599609
# Extracted links: 1201
# URL in for loop:  https://theintercept.com/theintercept/feed/?post_type=post&staff=-7
# Elapsed time: 5.364354372024536
# Extracted links: 1202
# URL in for loop:  https://theintercept.com/privacy-policy
# Elapsed time: 5.891213417053223
# Extracted links: 1202
# URL in for loop:  https://twitter.com/intent/tweet?text=Livestream%3A%20The%20battle%20for%20paradise%20%E2%80%94%20resisting%20disaster%20capitalism%20in%20Puerto%20Rico%20https%3A%2F%2Ftheintercept.com%2Fpuerto-rico%2F
# Elapsed time: 5.275022029876709
# Extracted links: 1202
# URL in for loop:  mailto:ali.gharib@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:ali.gharib@theintercept.com'
# Elapsed time: 5.0050506591796875
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2018/06/15/will-the-u-s-ever-give-up-its-nukes/?comments=1#comments
# Elapsed time: 5.46610689163208
# Extracted links: 1203
# URL in for loop:  mailto:corrections@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:corrections@theintercept.com'
# Elapsed time: 5.005647420883179
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/akilharris/
# Elapsed time: 7.125183343887329
# Extracted links: 1204
# URL in for loop:  https://theintercept.com/staff/peter-maass/feed/?rss
# Elapsed time: 5.716852903366089
# Extracted links: 1556
# URL in for loop:  https://theintercept.com/staff/rogerhodge/
# Elapsed time: 6.313867568969727
# Extracted links: 1561
# URL in for loop:  https://theintercept.com/staff/ryan-gallagher/
# Elapsed time: 5.6018455028533936
# Extracted links: 1568
# URL in for loop:  https://theintercept.com/podcasts/#deconstructed
# Elapsed time: 5.4303879737854
# Extracted links: 1568
# URL in for loop:  https://theintercept.com/donate
# Elapsed time: 5.512567043304443
# Extracted links: 1569
# URL in for loop:  mailto:briahna.gray@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:briahna.gray@theintercept.com'
# Elapsed time: 5.003759145736694
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/katemyers/
# Elapsed time: 5.798803091049194
# Extracted links: 1572
# URL in for loop:  mailto:podcasts@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:podcasts@theintercept.com'
# Elapsed time: 5.005157947540283
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/robertmackey/
# Elapsed time: 8.006540775299072
# Extracted links: 1583
# URL in for loop:  mailto:vanessa.gezari@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:vanessa.gezari@theintercept.com'
# Elapsed time: 5.005193471908569
# Main Loop: HTML not extracted
# URL in for loop:  mailto:moiz.syed@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:moiz.syed@theintercept.com'
# Elapsed time: 5.005657911300659
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/ryangrim/
# Elapsed time: 5.487275123596191
# Extracted links: 1588
# URL in for loop:  https://theintercept.com/staff/ryan-gallagher/feed/?rss
# Elapsed time: 5.694040536880493
# Extracted links: 1799
# URL in for loop:  https://theintercept.com/series/the-fbis-secret-rules/
# Elapsed time: 13.592504024505615
# Extracted links: 1828
# URL in for loop:  mailto:john.thomason@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:john.thomason@theintercept.com'
# Elapsed time: 5.003683090209961
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2018/06/08/elizabeth-warren-v-the-district-of-corruption/
# Elapsed time: 6.242476463317871
# Extracted links: 1834
# URL in for loop:  https://theintercept.com/staff/andreajones/
# Elapsed time: 7.224771976470947
# Extracted links: 1837
# URL in for loop:  mailto:membership@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:membership@theintercept.com'
# Elapsed time: 5.003081321716309
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/about/#membership
# Elapsed time: 5.4709155559539795
# Extracted links: 1837
# URL in for loop:  https://theintercept.com/greenwald?menu=1
# Elapsed time: 11.801880359649658
# Extracted links: 1838
# URL in for loop:  https://theintercept.com/2018/06/14/nypd-gang-database-city-council-dermot-shea?menu=1
# Elapsed time: 6.377784252166748
# Extracted links: 1839
# URL in for loop:  mailto:zaid.jilani@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:zaid.jilani@theintercept.com'
# Elapsed time: 5.016950368881226
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/podcasts?menu=1
# Elapsed time: 5.803510427474976
# Extracted links: 1842
# URL in for loop:  https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftheintercept.com%2Fpolicies%2F
# Elapsed time: 6.785958290100098
# Extracted links: 1848
# URL in for loop:  https://theintercept.com/staff/sheelagh-mcneill/
# Elapsed time: 5.696211814880371
# Extracted links: 1852
# URL in for loop:  https://theintercept.com/staff/arielzambelich/
# Elapsed time: 7.367154836654663
# Extracted links: 1854
# URL in for loop:  mailto:lauren.feeney@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:lauren.feeney@theintercept.com'
# Elapsed time: 5.1163036823272705
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/about/#publisher
# Elapsed time: 5.708681106567383
# Extracted links: 1854
# URL in for loop:  https://theintercept.com/2018/05/26/professor-da-rede-publica-de-sao-paulo-cata-lixo-para-sobreviver/
# Elapsed time: 5.914808988571167
# Extracted links: 1865
# URL in for loop:  https://theintercept.com/terms-use/www.jamsadr.com
# Elapsed time: 6.815398931503296
# Extracted links: 1866
# URL in for loop:  https://theintercept.com/document/2018/06/01/vr-systems-phishing-alert-to-mecklenburg-county/
# Elapsed time: 5.638606786727905
# Extracted links: 1867
# URL in for loop:  https://theintercept.com/staff/alicesperi/
# Elapsed time: 8.30845832824707
# Extracted links: 1872
# URL in for loop:  https://theintercept.com/staff/shaunking/
# Elapsed time: 7.710581302642822
# Extracted links: 1879
# URL in for loop:  https://theintercept.com/staff/alex-emmons/
# Elapsed time: 6.427072525024414
# Extracted links: 1887
# URL in for loop:  https://theintercept.com/brasil/newsletter/
# Elapsed time: 5.316560745239258
# Extracted links: 1888
# URL in for loop:  https://theintercept.com/policies
# Elapsed time: 5.8381187915802
# Extracted links: 1888
# URL in for loop:  mailto:murtaza.hussain@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:murtaza.hussain@theintercept.com'
# Elapsed time: 5.0036396980285645
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/document/2018/05/19/dfs-briefing-feb-2013/
# Elapsed time: 5.318831443786621
# Extracted links: 1889
# URL in for loop:  https://theintercept.com/2018/05/17/inside-the-barbaric-u-s-industry-of-dog-experimentation/
# Elapsed time: 5.55228066444397
# Extracted links: 1959
# URL in for loop:  https://theintercept.com/staff/glenn-greenwald/
# Elapsed time: 6.011791706085205
# Extracted links: 1962
# URL in for loop:  https://theintercept.com/staff/rashmeekumar/
# Elapsed time: 7.112258672714233
# Extracted links: 1969
# URL in for loop:  https://theintercept.com/terms-use?menu=1
# Elapsed time: 6.1301610469818115
# Extracted links: 1971
# URL in for loop:  https://theintercept.com/podcasts/?campaign=homepage-podcast#intercepted
# Elapsed time: 5.664846658706665
# Extracted links: 1971
# URL in for loop:  mailto:sheelagh.mcneill@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:sheelagh.mcneill@theintercept.com'
# Elapsed time: 5.002366304397583
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/feed/?lang=en
# Elapsed time: 5.854739189147949
# Extracted links: 2042
# URL in for loop:  https://theintercept.com/2018/06/15/will-the-u-s-ever-give-up-its-nukes?campaign=homepage-podcast-deconstructed&menu=1
# Elapsed time: 5.8454673290252686
# Extracted links: 2043
# URL in for loop:  https://theintercept.com/newsletter?menu=1
# Elapsed time: 5.395807981491089
# Extracted links: 2044
# URL in for loop:  https://theintercept.com/podcasts?campaign=homepage-podcast&menu=1
# Elapsed time: 5.883864641189575
# Extracted links: 2047
# URL in for loop:  https://theintercept.com/staff/ryan-devereaux/
# Elapsed time: 7.602665185928345
# Extracted links: 2054
# URL in for loop:  https://theintercept.com/donate?campaign=70146000000YxhuAAC&menu=1
# Elapsed time: 5.453785419464111
# Extracted links: 2055
# URL in for loop:  mailto:robert.mackey@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:robert.mackey@theintercept.com'
# Elapsed time: 5.003249168395996
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/glenn-greenwald/feed/?rss
# Elapsed time: 5.939342021942139
# Extracted links: 2491
# URL in for loop:  https://theintercept.com/staff/jonschwarz/
# Elapsed time: 5.464128255844116
# Extracted links: 2499
# URL in for loop:  https://theintercept.com/podcasts/deconstructed/
# Elapsed time: 5.881073236465454
# Extracted links: 2499
# URL in for loop:  mailto:miroslav.macala@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:miroslav.macala@theintercept.com'
# Elapsed time: 5.303073883056641
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2018/06/15/prosecutors-misconduct-criminal-justice-reform-texas/?comments=1#comments
# Elapsed time: 6.679727077484131
# Extracted links: 2500
# URL in for loop:  https://theintercept.com/staff/micah-lee/
# Elapsed time: 8.670708179473877
# Extracted links: 2508
# URL in for loop:  mailto:mariam.elba@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:mariam.elba@theintercept.com'
# Elapsed time: 5.110456943511963
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/jeremy-scahill/
# Elapsed time: 10.73867416381836
# Extracted links: 2514
# URL in for loop:  https://theintercept.com/staff/nick-pinto/
# Elapsed time: 7.524808168411255
# Extracted links: 2518
# URL in for loop:  mailto:liliana.segura@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:liliana.segura@theintercept.com'
# Elapsed time: 5.03557562828064
# Main Loop: HTML not extracted
# URL in for loop:  mailto:rodrigo.brandao@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:rodrigo.brandao@theintercept.com'
# Elapsed time: 5.126984596252441
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/aligharib/
# Elapsed time: 8.118763446807861
# Extracted links: 2521
# URL in for loop:  https://theintercept.com/staff/liliana-segura/feed/?rss
# Elapsed time: 6.729568004608154
# Extracted links: 2903
# URL in for loop:  https://theintercept.com/drone-papers/
# Elapsed time: 5.9311299324035645
# Extracted links: 2921
# URL in for loop:  mailto:tips@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:tips@theintercept.com'
# Elapsed time: 5.261187791824341
# Main Loop: HTML not extracted
# URL in for loop:  mailto:fishman@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:fishman@theintercept.com'
# Elapsed time: 5.125659942626953
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/document/2018/05/25/ellison-cleaver-letter-to-jeff-bezos/
# Elapsed time: 5.669389247894287
# Extracted links: 2922
# URL in for loop:  https://theintercept.com/staff/intercepted/
# Elapsed time: 10.898398160934448
# Extracted links: 2925
# URL in for loop:  mailto:lee.fang@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:lee.fang@theintercept.com'
# Elapsed time: 5.231526136398315
# Main Loop: HTML not extracted
# URL in for loop:  mailto:andrea.jones@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:andrea.jones@theintercept.com'
# Elapsed time: 5.00812292098999
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/donate?campaign=70146000000HLS1AAO&menu=1
# Elapsed time: 5.554573059082031
# Extracted links: 2926
# URL in for loop:  mailto:matthew.cole@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:matthew.cole@theintercept.com'
# Elapsed time: 5.002325534820557
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/talyacooper/
# Elapsed time: 7.599264621734619
# Extracted links: 2929
# URL in for loop:  mailto:shaun.king@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:shaun.king@theintercept.com'
# Elapsed time: 5.007086992263794
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/westleyhennighpalermo/
# Elapsed time: 7.102296829223633
# Extracted links: 2931
# URL in for loop:  https://theintercept.com/document/2018/05/11/cartas-do-carcere/
# Elapsed time: 5.316082954406738
# Extracted links: 2932
# URL in for loop:  mailto:rubina@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:rubina@theintercept.com'
# Elapsed time: 5.002679109573364
# Main Loop: HTML not extracted
# URL in for loop:  mailto:ryan.grim@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:ryan.grim@theintercept.com'
# Elapsed time: 5.002753973007202
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/rodrigobrandao/
# Elapsed time: 6.298058271408081
# Extracted links: 2934
# URL in for loop:  https://theintercept.com/staff/rubinafillion/
# Elapsed time: 6.873948812484741
# Extracted links: 2940
# URL in for loop:  https://theintercept.com/podcasts/#intercepted
# Elapsed time: 5.462897777557373
# Extracted links: 2940
# URL in for loop:  https://theintercept.com/2018/06/14/bay-area-muslim-leader-has-her-award-rescinded-by-inter-faith-group-after-pro-israel-activists-objected/?comments=1#comments
# Elapsed time: 6.189574241638184
# Extracted links: 2941
# URL in for loop:  https://theintercept.com/2018/02/16/trump-russia-election-hacking-investigation/
# Elapsed time: 7.234301805496216
# Extracted links: 2970
# URL in for loop:  https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftheintercept.com%2Fpuerto-rico%2F
# Elapsed time: 5.707266569137573
# Extracted links: 2976
# URL in for loop:  https://theintercept.com/document/2018/06/11/gangs-and-crews-of-new-york/
# Elapsed time: 5.370261192321777
# Extracted links: 2977
# URL in for loop:  mailto:sam.biddle@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:sam.biddle@theintercept.com'
# Elapsed time: 5.0064873695373535
# Main Loop: HTML not extracted
# URL in for loop:  mailto:micah.lee@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:micah.lee@theintercept.com'
# Elapsed time: 5.009322881698608
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/liliana-segura/
# Elapsed time: 8.41592264175415
# Extracted links: 2980
# URL in for loop:  https://theintercept.com/brasil?menu=1
# Elapsed time: 6.358790874481201
# Extracted links: 2981
# URL in for loop:  https://theintercept.com/staff/natasha-lennard/
# Elapsed time: 5.922216892242432
# Extracted links: 2986
# URL in for loop:  https://theintercept.com/staff/peter-maass/
# Elapsed time: 8.27032208442688
# Extracted links: 2989
# URL in for loop:  https://theintercept.com/staff/philipphubert/
# Elapsed time: 7.281466960906982
# Extracted links: 2992
# URL in for loop:  https://theintercept.com/staff/murtaza-hussain/
# Elapsed time: 6.029498100280762
# Extracted links: 2994
# URL in for loop:  https://theintercept.com/2015/01/21/spies-among-us-community-outreach-programs-muslims-blur-lines-outreach-intelligence/
# Elapsed time: 5.385233402252197
# Extracted links: 3017
# URL in for loop:  https://theintercept.com/staff/jordan-smith/
# Elapsed time: 6.142944574356079
# Extracted links: 3022
# URL in for loop:  https://theintercept.com/leak/
# Elapsed time: 5.4466729164123535
# Extracted links: 3022
# URL in for loop:  https://theintercept.com/document/2018/05/23/j20-defense-argues-prosecutors-withheld-exculpatory-evidence/
# Elapsed time: 5.356305837631226
# Extracted links: 3023
# URL in for loop:  https://theintercept.com/2018/04/12/trump-russia-intermediary-joseph-mifsud-missing-case-for-collusion/
# Elapsed time: 6.790855884552002
# Extracted links: 3062
# URL in for loop:  mailto:jeremy.scahill@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:jeremy.scahill@theintercept.com'
# Elapsed time: 5.006585597991943
# Main Loop: HTML not extracted
# URL in for loop:  mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fterms-use%2F
# ScrapeHTML: No connection adapters were found for 'mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fterms-use%2F'
# Elapsed time: 5.00471568107605
# Main Loop: HTML not extracted
# URL in for loop:  mailto:ariel.zambelich@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:ariel.zambelich@theintercept.com'
# Elapsed time: 5.002821207046509
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/lynndombek/
# Elapsed time: 7.091961145401001
# Extracted links: 3064
# URL in for loop:  https://theintercept.com/snowden-sidtoday/
# Elapsed time: 6.16978120803833
# Extracted links: 3073
# URL in for loop:  mailto:permissions@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:permissions@theintercept.com'
# Elapsed time: 5.008779287338257
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/about/#about-the-intercept
# Elapsed time: 5.491875886917114
# Extracted links: 3073
# URL in for loop:  https://theintercept.com/puerto-rico?menu=1
# Elapsed time: 5.432807207107544
# Extracted links: 3074
# URL in for loop:  https://theintercept.com/staff/travismannon/
# Elapsed time: 8.009632110595703
# Extracted links: 3082
# URL in for loop:  https://theintercept.com/staff/ryantate/
# Elapsed time: 7.978976488113403
# Extracted links: 3091
# URL in for loop:  https://theintercept.com/staff/johnthomason/
# Elapsed time: 8.082155704498291
# Extracted links: 3099
# URL in for loop:  https://theintercept.com/?menu=1#recently
# Elapsed time: 6.24453330039978
# Extracted links: 3099
# URL in for loop:  https://theintercept.com/podcasts/intercepted/faq
# Elapsed time: 5.4347453117370605
# Extracted links: 3100
# URL in for loop:  https://theintercept.com/staff/briahnagray/
# Elapsed time: 7.272580623626709
# Extracted links: 3102
# URL in for loop:  mailto:roger.hodge@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:roger.hodge@theintercept.com'
# Elapsed time: 5.006024599075317
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/feeds?menu=1
# Elapsed time: 5.435640811920166
# Extracted links: 3103
# URL in for loop:  https://theintercept.com/2018/05/23/isis-files-podcast-new-york-times-iraq/
# Elapsed time: 6.12120795249939
# Extracted links: 3141
# URL in for loop:  https://theintercept.com/staff/ryan-devereaux/feed/?rss
# Elapsed time: 5.956739664077759
# Extracted links: 3289
# URL in for loop:  https://theintercept.com/about?menu=1
# Elapsed time: 6.463927984237671
# Extracted links: 3294
# URL in for loop:  https://theintercept.com/newsletter/?campaign=Article-In
# Elapsed time: 5.381780385971069
# Extracted links: 3295
# URL in for loop:  https://theintercept.com/staff/jackdisidoro/
# Elapsed time: 7.11736273765564
# Extracted links: 3297
# URL in for loop:  mailto:rashmee.kumar@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:rashmee.kumar@theintercept.com'
# Elapsed time: 5.00695013999939
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/leefang/
# Elapsed time: 6.089322328567505
# Extracted links: 3302
# URL in for loop:  https://theintercept.com/2018/06/15/domestic-violence-asylum-jeff-sessions/?comments=1#comments
# Elapsed time: 6.246429920196533
# Extracted links: 3303
# URL in for loop:  https://theintercept.com/?menu=1#greenwald
# Elapsed time: 5.9879469871521
# Extracted links: 3303
# URL in for loop:  https://theintercept.com/2018/05/30/guilherme-boulos-glenn-greenwald-entrevista/
# Elapsed time: 6.4660115242004395
# Extracted links: 3304
# URL in for loop:  mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fpolicies%2F
# ScrapeHTML: No connection adapters were found for 'mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fpolicies%2F'
# Elapsed time: 5.005616903305054
# Main Loop: HTML not extracted
# URL in for loop:  https://trial-and-terror.theintercept.com/
# Elapsed time: 6.198256254196167
# Extracted links: 3315
# URL in for loop:  mailto:aida.chavez@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:aida.chavez@theintercept.com'
# Elapsed time: 5.004140853881836
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/sooheecho/
# Elapsed time: 6.258027076721191
# Extracted links: 3317
# URL in for loop:  https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftheintercept.com%2Fprivacy-policy%2F
# Elapsed time: 26.774301767349243
# Extracted links: 3323
# URL in for loop:  https://theintercept.com/2018/06/13/bipartisan-war-party-panics-as-kim-meets-trump?campaign=homepage-podcast-intercepted&menu=1
# Elapsed time: 6.504337549209595
# Extracted links: 3324
# URL in for loop:  https://theintercept.com/2018/06/11/new-york-gang-database-expanded-by-70-percent-under-mayor-bill-de-blasio/
# Elapsed time: 5.414808750152588
# Extracted links: 3338
# URL in for loop:  https://theintercept.com/staff/jimrisen/
# Elapsed time: 8.03657341003418
# Extracted links: 3342
# URL in for loop:  mailto:betsy.reed@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:betsy.reed@theintercept.com'
# Elapsed time: 5.003343820571899
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/document/2018/05/19/dfs-and-nsa-mutual-cooperation/
# Elapsed time: 5.325878620147705
# Extracted links: 3343
# URL in for loop:  https://theintercept.com/staff/micah-lee/feed/?rss
# Elapsed time: 5.798659086227417
# Extracted links: 3695
# URL in for loop:  mailto:jordan.smith@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:jordan.smith@theintercept.com'
# Elapsed time: 5.009854555130005
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/series?menu=1
# Elapsed time: 6.2478346824646
# Extracted links: 3696
# URL in for loop:  https://theintercept.com/2018/06/13/direita-bolsonaro-lula-judiciario/
# Elapsed time: 5.430783033370972
# Extracted links: 3706
# URL in for loop:  https://theintercept.com/document/2018/05/19/cyber-paper-japan-dfs/
# Elapsed time: 5.364636659622192
# Extracted links: 3707
# URL in for loop:  https://theintercept.com/feed/?mk=fl_is_on_feature_page&mv=1
# Elapsed time: 6.062767267227173
# Extracted links: 4035
# URL in for loop:  https://theintercept.com/staff/sambiddle/
# Elapsed time: 8.261160373687744
# Extracted links: 4043
# URL in for loop:  mailto:glenn.greenwald@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:glenn.greenwald@theintercept.com'
# Elapsed time: 5.003682613372803
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2018/06/14/nypd-gang-database-city-council-dermot-shea/?comments=1#comments
# Elapsed time: 6.746752500534058
# Extracted links: 4044
# URL in for loop:  https://theintercept.com/2017/05/16/help-us-sustain-and-expand-our-journalism/
# Elapsed time: 6.080888509750366
# Extracted links: 4051
# URL in for loop:  mailto:elise.swain@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:elise.swain@theintercept.com'
# Elapsed time: 5.005534648895264
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/about/#contact-us
# Elapsed time: 5.500742197036743
# Extracted links: 4051
# URL in for loop:  https://theintercept.com/document/2018/06/11/relatorio-de-municoes/
# Elapsed time: 5.342333793640137
# Extracted links: 4052
# URL in for loop:  https://theintercept.com/2018/06/13/marielle-franco-veradores-mortos/
# Elapsed time: 5.465685129165649
# Extracted links: 4060
# URL in for loop:  https://theintercept.com/the-intercepts-privacy-philosophy/
# Elapsed time: 5.917011260986328
# Extracted links: 4066
# URL in for loop:  https://theintercept.com/policies?menu=1
# Elapsed time: 5.856662273406982
# Extracted links: 4066
# URL in for loop:  https://theintercept.com/2018/06/15/prosecutors-misconduct-criminal-justice-reform-texas?menu=1
# Elapsed time: 5.857886791229248
# Extracted links: 4067
# URL in for loop:  mailto:ryan.tate@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:ryan.tate@theintercept.com'
# Elapsed time: 5.0058815479278564
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/miroslavmacala/
# Elapsed time: 5.769420146942139
# Extracted links: 4069
# URL in for loop:  https://theintercept.com/staff/cora/
# Elapsed time: 9.22737169265747
# Extracted links: 4074
# URL in for loop:  https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftheintercept.com%2Ffeeds%2F
# Elapsed time: 5.8961851596832275
# Extracted links: 4080
# URL in for loop:  https://theintercept.com/staff/betsyreed/
# Elapsed time: 7.048040866851807
# Extracted links: 4086
# URL in for loop:  https://theintercept.com/staff/maryamsaleh/
# Elapsed time: 8.260529518127441
# Extracted links: 4092
# URL in for loop:  https://theintercept.com/documents?menu=1
# Elapsed time: 5.825982570648193
# Extracted links: 4093
# URL in for loop:  https://theintercept.com/2017/05/31/the-numbers-dont-lie-white-far-right-terrorists-pose-a-clear-danger-to-us-all/
# Elapsed time: 6.195492506027222
# Extracted links: 4132
# URL in for loop:  mailto:cora.currier@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:cora.currier@theintercept.com'
# Elapsed time: 5.007852792739868
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/eliseswain/
# Elapsed time: 6.634701251983643
# Extracted links: 4136
# URL in for loop:  mailto:travis.mannon@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:travis.mannon@theintercept.com'
# Elapsed time: 5.005720853805542
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/privacy-policy?menu=1
# Elapsed time: 5.9292895793914795
# Extracted links: 4136
# URL in for loop:  https://theintercept.com/2018/06/13/bipartisan-war-party-panics-as-kim-meets-trump/?comments=1#comments
# Elapsed time: 5.678910732269287
# Extracted links: 4137
# URL in for loop:  https://theintercept.com/2018/06/11/governo-proposta-marielle/
# Elapsed time: 5.424091100692749
# Extracted links: 4153
# URL in for loop:  mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Ffeeds%2F
# ScrapeHTML: No connection adapters were found for 'mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Ffeeds%2F'
# Elapsed time: 5.004993915557861
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/feed/?lang=pt
# Elapsed time: 5.76627254486084
# Extracted links: 4296
# URL in for loop:  mailto:margot.williams@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:margot.williams@theintercept.com'
# Elapsed time: 5.005717039108276
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2018/04/22/to-defeat-isis-the-u-s-helped-turn-old-mosul-into-rubble-but-wont-help-rebuild-it/
# Elapsed time: 5.56700873374939
# Extracted links: 4315
# URL in for loop:  https://theintercept.com/donate/?campaign=70146000000ZE8TAAW
# Elapsed time: 5.433028221130371
# Extracted links: 4316
# URL in for loop:  https://theintercept.com/donate/?campaign=70146000000HLS1AAO&installmentPeriod=monthly
# Elapsed time: 5.420724391937256
# Extracted links: 4317
# URL in for loop:  https://theintercept.com/staff/alleenbrown/
# Elapsed time: 6.079510688781738
# Extracted links: 4325
# URL in for loop:  https://theintercept.com/staff/mariamelba/
# Elapsed time: 6.898457050323486
# Extracted links: 4329
# URL in for loop:  mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fpuerto-rico%2F
# ScrapeHTML: No connection adapters were found for 'mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fpuerto-rico%2F'
# Elapsed time: 5.007339239120483
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2018/06/06/the-persecution-of-reality-winner/
# Elapsed time: 6.0386412143707275
# Extracted links: 4339
# URL in for loop:  mailto:maryam.saleh@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:maryam.saleh@theintercept.com'
# Elapsed time: 5.0059285163879395
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/jeremy-scahill/feed/?rss
# Elapsed time: 6.428552150726318
# Extracted links: 4394
# URL in for loop:  https://theintercept.com/series/trump-and-russia/
# Elapsed time: 6.45261287689209
# Extracted links: 4395
# URL in for loop:  mailto:submissions@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:submissions@theintercept.com'
# Elapsed time: 5.002689361572266
# Main Loop: HTML not extracted
# URL in for loop:  mailto:alex.emmons@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:alex.emmons@theintercept.com'
# Elapsed time: 5.002427816390991
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/vanessagezari/
# Elapsed time: 7.1057562828063965
# Extracted links: 4398
# URL in for loop:  mailto:jon.schwarz@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:jon.schwarz@theintercept.com'
# Elapsed time: 5.002663612365723
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/moizsyed/
# Elapsed time: 5.9135212898254395
# Extracted links: 4403
# URL in for loop:  https://theintercept.com/third-party-table/
# Elapsed time: 5.944352149963379
# Extracted links: 4426
# URL in for loop:  https://theintercept.com/staff/deconstructed/
# Elapsed time: 6.158092021942139
# Extracted links: 4429
# URL in for loop:  https://theintercept.com/2018/06/13/abin-mais-poderes-nova-lei/
# Elapsed time: 5.394797325134277
# Extracted links: 4435
# URL in for loop:  https://theintercept.com/staff/laurenfeeney/
# Elapsed time: 8.29692554473877
# Extracted links: 4440
# URL in for loop:  https://theintercept.com/brasil/staff/
# Elapsed time: 5.855686902999878
# Extracted links: 4464
# URL in for loop:  https://theintercept.com/2018/03/20/larry-krasner-philadelphia-da/
# Elapsed time: 5.3990254402160645
# Extracted links: 4478
# URL in for loop:  https://theintercept.com/2018/06/01/the-war-on-immigrants/
# Elapsed time: 8.33924674987793
# Extracted links: 4484
# URL in for loop:  https://theintercept.com/podcasts/intercepted/
# Elapsed time: 5.623033046722412
# Extracted links: 4490
# URL in for loop:  https://theintercept.com/2018/06/15/cve-grants-muslim-surveillance-brennan-center?menu=1
# Elapsed time: 5.474968194961548
# Extracted links: 4491
# URL in for loop:  mailto:ryan.devereaux@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:ryan.devereaux@theintercept.com'
# Elapsed time: 5.003885984420776
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/features?menu=1
# Elapsed time: 6.545411586761475
# Extracted links: 4492
#
# Number of Urls: 251
# Process Time: 1538.7463400363922
# --------------------------------------------------------------
# done_urls:  223
# (urls - done_urls):  1129
# LOOP counter:  3
# --------------------
# URL in for loop:  https://theintercept.com/2017/01/31/despite-anti-profiling-rules-the-fbi-uses-race-and-religion-when-deciding-who-to-target/
# Elapsed time: 9.125991344451904
# Extracted links: 4522
# URL in for loop:  https://theintercept.com/2018/06/11/governo-proposta-marielle?menu=1
# Elapsed time: 6.180799245834351
# Extracted links: 4523
# URL in for loop:  https://theintercept.com/2017/10/28/josh-walker-anarchist-cookbook-terrorism-act-uk/
# Elapsed time: 6.149901390075684
# Extracted links: 4532
# URL in for loop:  https://theintercept.com/wp-uploads/sites/1/2016/10/LaurenFeeney.asc
# Elapsed time: 5.688322305679321
# Extracted links: 4532
# URL in for loop:  https://theintercept.com/snowden-sidtoday/4389902-can-motor-city-manufacture-some-arabic-language/
# Elapsed time: 5.494168281555176
# Extracted links: 4536
# URL in for loop:  https://theintercept.com/staff/talyacooper?menu=1
# Elapsed time: 8.621125936508179
# Extracted links: 4537
# URL in for loop:  https://theintercept.com/2017/09/14/negligencias-descuidos-e-outras-historias-da-nsa/
# Elapsed time: 6.321995735168457
# Extracted links: 4553
# URL in for loop:  mailto:juliana.goncalves@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:juliana.goncalves@theintercept.com'
# Elapsed time: 5.002585411071777
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2018/06/05/pedro-sanchez-governo-socialista-espanhol/
# Elapsed time: 6.1181700229644775
# Extracted links: 4563
# URL in for loop:  mailto:philipp.hubert@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:philipp.hubert@theintercept.com'
# Elapsed time: 5.0061423778533936
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/jonschwarz?menu=1
# Elapsed time: 8.519493818283081
# Extracted links: 4564
# URL in for loop:  https://theintercept.com/staff/micah-lee/feed/?rss#_ftn6
# Elapsed time: 6.063556432723999
# Extracted links: 4564
# URL in for loop:  https://theintercept.com/wp-uploads/sites/1/2015/01/BetsyReedPGP.asc
# Elapsed time: 5.769547462463379
# Extracted links: 4564
# URL in for loop:  https://theintercept.com/document/2017/01/31/guidance-on-guardian-assessments-2013/
# Elapsed time: 6.067410945892334
# Extracted links: 4565
# URL in for loop:  https://theintercept.com/2017/09/06/how-right-wing-extremists-stalk-dox-and-harass-their-enemies/
# Elapsed time: 5.486066818237305
# Extracted links: 4588
# URL in for loop:  https://theintercept.com/surveillance-catalogue/sagem-ot488-498/
# Elapsed time: 5.772917985916138
# Extracted links: 4592
# URL in for loop:  https://theintercept.com/2018/04/10/district-attorney-race-2018-police/
# Elapsed time: 6.098501443862915
# Extracted links: 4625
# URL in for loop:  https://theintercept.com/2018/06/15/domestic-violence-asylum-jeff-sessions?comments=1&menu=1
# Elapsed time: 6.291721820831299
# Extracted links: 4626
# URL in for loop:  https://twitter.com/intent/tweet?text=Subscribe%20to%20%23Intercepted%2C%20a%20weekly%20podcast%20hosted%20by%20%40jeremyscahill%20https%3A%2F%2Ftheintercept.com%2Fpodcasts%2Fintercepted%2F
# Elapsed time: 5.300696849822998
# Extracted links: 4626
# URL in for loop:  https://theintercept.com/2018/06/08/elizabeth-warren-v-the-district-of-corruption/?comments=1#comments
# Elapsed time: 6.447010517120361
# Extracted links: 4627
# URL in for loop:  https://theintercept.com/document/2017/01/31/domestic-investigations-and-operations-guide/fbi-hid-doubts-about-reliability-of-stingray-evidence-behind-redaction-marks/
# Elapsed time: 6.741773843765259
# Extracted links: 4628
# URL in for loop:  https://theintercept.com/2018/02/22/civilian-casualties-soared-in-iraq-and-syria-in-2017-was-trumps-bloodthirsty-rhetoric-to-blame/
# Elapsed time: 6.084266185760498
# Extracted links: 4635
# URL in for loop:  https://theintercept.com/wp-uploads/sites/1/2016/05/moizsyedPUBLIC.asc
# Elapsed time: 5.696446180343628
# Extracted links: 4635
# URL in for loop:  https://theintercept.com/2018/04/20/andrew-cuomo-voting-rights-parolees-cynthia-nixon/
# Elapsed time: 6.212672710418701
# Extracted links: 4653
# URL in for loop:  https://theintercept.com/2018/06/08/racismo-direito-puc/
# Elapsed time: 5.4278411865234375
# Extracted links: 4659
# URL in for loop:  https://theintercept.com/surveillance-catalogue/ics2/
# Elapsed time: 5.487923860549927
# Extracted links: 4663
# URL in for loop:  https://theintercept.com/2017/12/22/cliven-bundy-case-ranch-standoff-fbi/
# Elapsed time: 6.325693607330322
# Extracted links: 4676
# URL in for loop:  mailto:ryan.gallagher@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:ryan.gallagher@theintercept.com'
# Elapsed time: 5.003407001495361
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/surveillance-catalogue/nemo-handy-n95/
# Elapsed time: 5.571254730224609
# Extracted links: 4680
# URL in for loop:  https://theintercept.com/2018/03/12/tigerswan-dapl-private-security-climate-disaster-response/
# Elapsed time: 8.526772499084473
# Extracted links: 4712
# URL in for loop:  mailto:alice.speri@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:alice.speri@theintercept.com'
# Elapsed time: 5.007924318313599
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/staff/micah-lee/feed/?rss#groups
# Elapsed time: 5.99164605140686
# Extracted links: 4712
# ...
# Elapsed time: 5.904805660247803
# Extracted links: 14355
# URL in for loop:  https://theintercept.com/snowden-sidtoday/3676057-the-u-s-marshals-service-a-new-sigint-customer/
# Elapsed time: 5.523379325866699
# Extracted links: 14356
# URL in for loop:  https://theintercept.com/2017/09/21/shaun-king-intercept-vanessa-gezari-maryam-saleh-aida-chavez-kate-aronoff-rachel-m-cohen/
# Elapsed time: 6.120481967926025
# Extracted links: 14365
# URL in for loop:  https://theintercept.com/2015/12/16/a-secret-catalogue-of-government-gear-for-spying-on-your-cellphone/
# Elapsed time: 5.859126567840576
# Extracted links: 14392
# URL in for loop:  https://theintercept.com/2018/01/30/u-k-court-finds-governments-surveillance-law-unlawful/
# Elapsed time: 6.122567653656006
# Extracted links: 14398
# URL in for loop:  https://theintercept.com/2018/06/12/the-democratic-partys-2018-view-of-identity-politics-is-confusing-and-thus-appears-cynical-and-opportunistic/
# Elapsed time: 5.418553352355957
# Extracted links: 14407
# URL in for loop:  https://theintercept.com/2017/05/01/cybersecurity-for-the-people-how-to-keep-your-chats-truly-private-with-signal/#retention
# Elapsed time: 5.506647825241089
# Extracted links: 14407
# URL in for loop:  https://theintercept.com/surveillance-catalogue/garwind-blos-pod/
# Elapsed time: 5.553447246551514
# Extracted links: 14411
# URL in for loop:  https://theintercept.com/snowden-sidtoday/4389715-the-london-bombings-an-insider-s-view/
# Elapsed time: 5.423730850219727
# Extracted links: 14412
# URL in for loop:  https://theintercept.com/2016/06/10/as-brasilias-corruption-is-exposed-lawmakers-try-to-criminalize-dissent/
# Elapsed time: 7.510399341583252
# Extracted links: 14443
# URL in for loop:  https://theintercept.com/2017/05/01/cybersecurity-for-the-people-how-to-keep-your-chats-truly-private-with-signal/#images
# Elapsed time: 6.265108108520508
# Extracted links: 14443
# URL in for loop:  https://theintercept.com/2018/02/07/trumps-military-parade-is-ridiculous-but-hes-not-the-first-u-s-politician-to-use-humvees-and-f-16s-as-props/
# Elapsed time: 6.229883432388306
# Extracted links: 14449
# URL in for loop:  https://theintercept.com/2017/03/14/shannon-hurd-got-a-life-sentence-for-stealing-14-then-he-died-in-prison-from-untreated-cancer/
# Elapsed time: 6.2207653522491455
# Extracted links: 14458
# URL in for loop:  https://theintercept.com/staff/brunadelara/
# Elapsed time: 7.769886016845703
# Extracted links: 14461
# URL in for loop:  https://theintercept.com/2017/04/24/nsa-kept-watch-over-democratic-and-republican-conventions-snowden-documents-reveal
# Elapsed time: 6.183518648147583
# Extracted links: 14461
# URL in for loop:  https://theintercept.com/2018/06/13/direita-bolsonaro-lula-judiciario/?comments=1#comments
# Elapsed time: 6.730303764343262
# Extracted links: 14482
# URL in for loop:  https://theintercept.com/2016/06/13/stop-exploiting-lgbt-issues-to-demonize-islam-and-justify-anti-muslim-policies/
# Elapsed time: 6.233824729919434
# Extracted links: 14547
# URL in for loop:  https://theintercept.com/2017/11/28/climate-change-cop23-michael-bloomberg-jerry-brown/
# Elapsed time: 6.220102310180664
# Extracted links: 14553
# URL in for loop:  https://theintercept.com/2018/04/20/elliott-broidy-trump-russia-sanctions/
# Elapsed time: 6.1499927043914795
# Extracted links: 14568
# URL in for loop:  https://theintercept.com/2018/05/17/inside-the-barbaric-u-s-industry-of-dog-experimentation?menu=1
# Elapsed time: 6.379092216491699
# Extracted links: 14569
# URL in for loop:  https://theintercept.com/2016/08/10/iraqi-insurgents-stymied-the-nsa-and-other-highlights-from-263-internal-agency-reports/#cia
# Elapsed time: 6.38311505317688
# Extracted links: 14637
# URL in for loop:  https://theintercept.com/2018/03/01/iraq-porn-nsa-snowden-files-sidtoday/
# Elapsed time: 5.538222789764404
# Extracted links: 14651
# URL in for loop:  https://theintercept.com/2017/05/31/the-numbers-dont-lie-white-far-right-terrorists-pose-a-clear-danger-to-us-all/?comments=1#comments
# Elapsed time: 8.769831418991089
# Extracted links: 15073
# URL in for loop:  https://theintercept.com/2018/06/06/neymar-copa-selecao-impeachment/
# Elapsed time: 6.033717393875122
# Extracted links: 15080
# URL in for loop:  https://theintercept.com/staff/rodrigobrandao?menu=1
# Elapsed time: 7.276066303253174
# Extracted links: 15081
# URL in for loop:  mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fdonor-faq%2F
# ScrapeHTML: No connection adapters were found for 'mailto:?subject=&body=https%3A%2F%2Ftheintercept.com%2Fdonor-faq%2F'
# Elapsed time: 5.007475852966309
# Main Loop: HTML not extracted
# URL in for loop:  https://twitter.com/intent/tweet?text=The%20Intercept%E2%80%99s%20Changemakers%20%E2%80%94%20Our%20Donor%20Hall%20of%20Fame%20https%3A%2F%2Ftheintercept.com%2Fdonor-roll%2F
# Elapsed time: 5.26065993309021
# Extracted links: 15081
# URL in for loop:  https://theintercept.com/staff/micah-lee/feed/?rss#images
# Elapsed time: 5.930462837219238
# Extracted links: 15081
# URL in for loop:  mailto:leandro.demori@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:leandro.demori@theintercept.com'
# Elapsed time: 5.006182670593262
# Main Loop: HTML not extracted
# URL in for loop:  https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftheintercept.com%2Fdonor-privacy%2F
# Elapsed time: 5.948547840118408
# Extracted links: 15087
# URL in for loop:  https://theintercept.com/surveillance-catalogue/radiance/
# Elapsed time: 5.6008524894714355
# Extracted links: 15091
# URL in for loop:  https://theintercept.com/2018/06/14/bay-area-muslim-leader-has-her-award-rescinded-by-inter-faith-group-after-pro-israel-activists-objected?comments=1&menu=1
# Elapsed time: 6.297354698181152
# Extracted links: 15092
# URL in for loop:  https://theintercept.com/2018/03/21/marielle-franco-death-brazil-violence-police/
# Elapsed time: 6.3217291831970215
# Extracted links: 15098
# URL in for loop:  https://www.facebook.com/a/language.php?l=pt_BR&lref=https%3A%2F%2Fm.facebook.com%2Flogin.php%3Fskip_api_login%3D1%26api_key%3D966242223397117%26signed_next%3D1%26next%3Dhttps%253A%252F%252Fm.facebook.com%252Fsharer%252Fsharer.php%253Fu%253Dhttps%25253A%25252F%25252Ftheintercept.com%25252Fprivacy-policy%25252F%26cancel_url%3Dhttps%253A%252F%252Fm.facebook.com%252Fdialog%252Fclose_window%252F%253Fapp_id%253D966242223397117%2526connect%253D0%2523_%253D_%26display%3Dtouch%26locale%3Den_US&index=2&gfid=AQD24_2nSh70OSgJ&ref_component=mbasic_footer&ref_page=XLoginController&locale2=en_US&refid=9
# Elapsed time: 5.815983772277832
# Extracted links: 15110
# URL in for loop:  https://theintercept.com/2017/05/01/cybersecurity-for-the-people-how-to-keep-your-chats-truly-private-with-signal/?comments=1#comments
# Elapsed time: 7.06934666633606
# Extracted links: 15194
# URL in for loop:  https://theintercept.com/2018/03/10/poderosa-alianca-global-espionagem/
# Elapsed time: 5.42884635925293
# Extracted links: 15202
# URL in for loop:  https://theintercept.com/2018/02/14/alt-right-campus-free-speech-adl-splc?menu=1
# Elapsed time: 6.233979225158691
# Extracted links: 15203
# URL in for loop:  https://theintercept.com/2018/05/14/ivanka-trump-opens-u-s-embassy-jerusalem-israeli-massacre-palestinians/
# Elapsed time: 5.436290502548218
# Extracted links: 15260
# URL in for loop:  mailto:bruna.delara@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:bruna.delara@theintercept.com'
# Elapsed time: 5.006305932998657
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/2017/11/22/bosnia-ratko-mladic-verdict-siege-warfare-yemen/
# Elapsed time: 6.189541339874268
# Extracted links: 15268
# URL in for loop:  https://theintercept.com/2017/01/31/secret-rules-make-it-pretty-easy-for-the-fbi-to-spy-on-journalists-2/
# Elapsed time: 8.437036275863647
# Extracted links: 15296
# URL in for loop:  https://theintercept.com/2016/03/24/blackwater-founder-erik-prince-under-federal-investigation/
# Elapsed time: 6.134994745254517
# Extracted links: 15308
# URL in for loop:  https://theintercept.com/staff/jimrisen?menu=1
# Elapsed time: 8.173396348953247
# Extracted links: 15309
# URL in for loop:  https://theintercept.com/2017/01/31/hidden-loopholes-allow-fbi-agents-to-infiltrate-political-and-religious-groups/
# Elapsed time: 9.251090049743652
# Extracted links: 15336
# URL in for loop:  https://www.facebook.com/a/language.php?l=es_LA&lref=https%3A%2F%2Fm.facebook.com%2Flogin.php%3Fskip_api_login%3D1%26api_key%3D966242223397117%26signed_next%3D1%26next%3Dhttps%253A%252F%252Fm.facebook.com%252Fsharer%252Fsharer.php%253Fu%253Dhttps%25253A%25252F%25252Ftheintercept.com%25252Fterms-use%25252F%26cancel_url%3Dhttps%253A%252F%252Fm.facebook.com%252Fdialog%252Fclose_window%252F%253Fapp_id%253D966242223397117%2526connect%253D0%2523_%253D_%26display%3Dtouch%26locale%3Den_US&index=1&gfid=AQAlDdUnMXYZ45b4&ref_component=mbasic_footer&ref_page=XLoginController&locale2=en_US&refid=9
# Elapsed time: 5.815530776977539
# Extracted links: 15348
# URL in for loop:  https://theintercept.com/surveillance-catalogue/boeingschiebel-s100/
# Elapsed time: 5.582383394241333
# Extracted links: 15352
# URL in for loop:  https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftheintercept.com%2Fpodcasts%2Fintercepted%2F
# Elapsed time: 6.041640520095825
# Extracted links: 15358
# URL in for loop:  https://theintercept.com/document/2018/05/11/cartas-do-carcere?menu=1
# Elapsed time: 5.959612607955933
# Extracted links: 15359
# URL in for loop:  https://theintercept.com/document/2018/02/17/computer-network-exploitation-presentation
# Elapsed time: 5.867182493209839
# Extracted links: 15360
# URL in for loop:  https://theintercept.com/wp-uploads/sites/1/2017/01/0BF157E3-1485537791.asc
# Elapsed time: 5.793462753295898
# Extracted links: 15360
# URL in for loop:  https://theintercept.com/2016/08/02/como-enviar-informacoes-para-the-intercept/
# Elapsed time: 5.405589580535889
# Extracted links: 15371
# URL in for loop:  https://twitter.com/intent/tweet?text=Frequently%20Asked%20Questions%20About%20Donating%20to%20The%20Intercept%20https%3A%2F%2Ftheintercept.com%2Fdonor-faq%2F
# Elapsed time: 5.26748514175415
# Extracted links: 15371
# URL in for loop:  https://theintercept.com/snowden-sidtoday#archive
# Elapsed time: 6.429638385772705
# Extracted links: 15371
# URL in for loop:  https://theintercept.com/2016/05/14/orange-county-scandal-jailhouse-informants?menu=1
# Elapsed time: 15.11432671546936
# Extracted links: 15372
# URL in for loop:  https://theintercept.com/staff/ryan-gallagher?menu=1
# Elapsed time: 6.29734992980957
# Extracted links: 15373
# URL in for loop:  mailto:elise.swain@theintercept.com
# ScrapeHTML: No connection adapters were found for 'mailto:elise.swain@theintercept.com'
# Elapsed time: 5.007861137390137
# Main Loop: HTML not extracted
# URL in for loop:  https://theintercept.com/surveillance-catalogue/windjammer/
# Elapsed time: 5.604438066482544
# Extracted links: 15377
# URL in for loop:  https://theintercept.com/staff/cecilia-olliveira-brasil/
# Elapsed time: 8.067981481552124
# Extracted links: 15381
# URL in for loop:  https://static.theintercept.com/sidtoday/SIDtoday-03_01_2018.zip
# Elapsed time: 108.79758405685425
# ---------------------------------------------------------------------------
# DocumentTooLarge                          Traceback (most recent call last)
# <ipython-input-5-c90d7f26ffbe> in <module>()
#      35
#      36             # insert dict into db document
# ---> 37             htmlCollection.insert_one(data)
#      38
#      39             # record url in "done" collection
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     681             self._insert(document,
#     682                          bypass_doc_val=bypass_document_validation,
# --> 683                          session=session),
#     684             self.write_concern.acknowledged)
#     685
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     597             return self._insert_one(
#     598                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 599                 bypass_doc_val, session)
#     600
#     601         ids = []
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     577
#     578             result = self.__database.client._retryable_write(
# --> 579                 True, _insert_command, session)
#     580             _check_write_command_response(result)
#     581         else:
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1100         """Internal retryable write helper."""
#    1101         with self._tmp_session(session) as s:
# -> 1102             return self._retry_with_session(retryable, func, s, None)
#    1103
#    1104     def __reset_server(self, address):
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1077                         # Reset the transaction id and retry the operation.
#    1078                         session._retry_transaction_id()
# -> 1079                     return func(session, sock_info, retryable)
#    1080             except ServerSelectionTimeoutError:
#    1081                 if is_retrying():
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     574                     session=session,
#     575                     client=self.__database.client,
# --> 576                     retryable_write=retryable_write)
#     577
#     578             result = self.__database.client._retryable_write(
#
# ~\Anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     520         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     521         except BaseException as error:
# --> 522             self._raise_connection_failure(error)
#     523
#     524     def send_message(self, message, max_doc_size):
#
# ~\Anaconda3\lib\site-packages\pymongo\pool.py in _raise_connection_failure(self, error)
#     675             _raise_connection_failure(self.address, error)
#     676         else:
# --> 677             raise error
#     678
#     679     def __eq__(self, other):
#
# ~\Anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     515                            self.max_bson_size, read_concern,
#     516                            parse_write_concern_error=parse_write_concern_error,
# --> 517                            collation=collation)
#     518         except OperationFailure:
#     519             raise
#
# ~\Anaconda3\lib\site-packages\pymongo\network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation)
#     105             and size > max_bson_size + message._COMMAND_OVERHEAD):
#     106         message._raise_document_too_large(
# --> 107             name, size, max_bson_size + message._COMMAND_OVERHEAD)
#     108
#     109     if publish:
#
# ~\Anaconda3\lib\site-packages\pymongo\message.py in _raise_document_too_large(operation, doc_size, max_size)
#     703                                " - the connected server supports"
#     704                                " BSON document sizes up to %d"
# --> 705                                " bytes." % (doc_size, max_size))
#     706     else:
#     707         # There's nothing intelligent we can say
#
# DocumentTooLarge: BSON document too large (18687095 bytes) - the connected server supports BSON document sizes up to 16793598 bytes.

# %%
#sc.scrapeHTML("mailto:mhager3@hotmail.com", htmlCollection, done_urls)
