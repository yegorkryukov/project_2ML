# %%
# Dependencies
import re
import pymongo
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
def GetLinks(db_name):
    
    # Get database from Mongo
    db = client[db_name]
    
    # Get all documents from HTML_pages collection
    documents = db.HTML_pages.find()
    
    # Count the number of documents
    count = documents.count()

    # Create dictionary to count the number of external links
    links = {'politico.com':0, 'theamericanconservative.com':0, 'nypost.com':0, 'motherjones.com':0, 'breitbart.com':0,
             'bbc.com':0, 'msnbc.com':0, 'slate.com':0, 'oann.com':0, 'foxnews.com':0, 'theintercept.com':0,
             'theguardian.com':0, 'thedailybeast.com':0, 'newrepublic.com':0, 'washingtontimes.com':0, 'washingtonpost.com':0,
             'nationalreview.com':0, 'reason.com':0, 'thefiscaltimes.com':0, 'thehill.com':0}

    # Counter used to track progress
    i = 1

    # Iterate through each document
    for document in documents:

        # Get the HTML item in the document
        html = document['html']
        
        # Print progress
        #print(str(round((i / count)*100, 2))+"%")
        print(str(i) + "/" + str(count))
        
        # Convert string to BeautifulSoup object 
        soup = bs(html, 'lxml')

        # Find all anchor tags and loop through each one
        for url in soup.findAll('a'): 
                      
            # Convert url to string
            url = str(url)

            try:
                # Find where 'www.' and '.com' are in the url string
                start = url.index("www.") + 4
                end = url.index(".com") + 4

                # Splice external link from url
                ext_link = url[start:end]

                # Increment dictionary key/value pair
                links[ext_link] += 1

            # Error handling
            except (KeyError, ValueError):
                pass

        # Increment progress counter
        i += 1

    # Return results
    return(links)

# %%
#amercons_links = GetLinks("amercons_db")
#bbc_links = GetLinks("bbc_db")
#breitbart_links = GetLinks("breitbart_db")
#foxnews_links = GetLinks("foxnews_db")
#guardian_links = GetLinks("guardian_db")
#hill_links = GetLinks("hill_db")
#msnbc_links = GetLinks("msnbc_db")
#natrev_links = GetLinks("natrev_db")
#nypost_links = GetLinks("nypost_db")
#oann_links = GetLinks("oann_db")
politico_links = GetLinks("politico_db")
#reason_links = GetLinks("reason_db")
#tft_links = GetLinks("tft_db")
#washpost_links = GetLinks("washpost_db")       
#washtimes_links = GetLinks("washtimes_db")
#slate_links = GetLinks("slate_db")
#mj_links = GetLinks("mj_db")
#nr_links = GetLinks("nr_db")
#db_links = GetLInks("db_db")
#intercept_links = GetLinks("intercept_db")
# Out:
# 1/8585
# 2/8585
# 3/8585
# 4/8585
# 5/8585
# 6/8585
# 7/8585
# 8/8585
# 9/8585
# 10/8585
# 11/8585
# 12/8585
# 13/8585
# 14/8585
# 15/8585
# 16/8585
# 17/8585
# 18/8585
# 19/8585
# 20/8585
# 21/8585
# 22/8585
# 23/8585
# 24/8585
# 25/8585
# 26/8585
# 27/8585
# 28/8585
# 29/8585
# 30/8585
# 31/8585
# 32/8585
# 33/8585
# 34/8585
# 35/8585
# 36/8585
# 37/8585
# 38/8585
# 39/8585
# 40/8585
# 41/8585
# 42/8585
# 43/8585
# 44/8585
# 45/8585
# 46/8585
# 47/8585
# 48/8585
# 49/8585
# 50/8585
# 51/8585
# 52/8585
# 53/8585
# 54/8585
# 55/8585
# 56/8585
# 57/8585
# 58/8585
# 59/8585
# 60/8585
# 61/8585
# 62/8585
# 63/8585
# 64/8585
# 65/8585
# 66/8585
# 67/8585
# 68/8585
# 69/8585
# 70/8585
# 71/8585
# 72/8585
# 73/8585
# 74/8585
# 75/8585
# 76/8585
# 77/8585
# 78/8585
# 79/8585
# 80/8585
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-46-e3532037bdce> in <module>()
#       9 #nypost_links = GetLinks("nypost_db")
#      10 #oann_links = GetLinks("oann_db")
# ---> 11 politico_links = GetLinks("politico_db")
#      12 #reason_links = GetLinks("reason_db")
#      13 #tft_links = GetLinks("tft_db")
#
# <ipython-input-7-141ae752dc80> in GetLinks(db_name)
#      38
#      39             # Convert url to string
# ---> 40             url = str(url)
#      41
#      42             try:
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __unicode__(self)
#    1090
#    1091     def __unicode__(self):
# -> 1092         return self.decode()
#    1093
#    1094     def __str__(self):
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in decode(self, indent_level, eventual_encoding, formatter)
#    1178             indent_contents = None
#    1179         contents = self.decode_contents(
# -> 1180             indent_contents, eventual_encoding, formatter)
#    1181
#    1182         if self.hidden:
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in decode_contents(self, indent_level, eventual_encoding, formatter)
#    1247             elif isinstance(c, Tag):
#    1248                 s.append(c.decode(indent_level, eventual_encoding,
# -> 1249                                   formatter))
#    1250             if text and indent_level and not self.name == 'pre':
#    1251                 text = text.strip()
#
# ... last 2 frames repeated, from the frame below ...
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in decode(self, indent_level, eventual_encoding, formatter)
#    1178             indent_contents = None
#    1179         contents = self.decode_contents(
# -> 1180             indent_contents, eventual_encoding, formatter)
#    1181
#    1182         if self.hidden:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
db = client['politico_db']
documents = db.HTML_pages.find()

soup = bs(documents[546]['html'], 'lxml')

x = soup.findAll('a')
print(x)
#documents[546]['url']
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-10-10f784b7eee3> in <module>()
#       5
#       6 x = soup.findAll('a')
# ----> 7 print(x)
#       8 #documents[546]['url']
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __unicode__(self)
#    1090
#    1091     def __unicode__(self):
# -> 1092         return self.decode()
#    1093
#    1094     def __str__(self):
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in decode(self, indent_level, eventual_encoding, formatter)
#    1178             indent_contents = None
#    1179         contents = self.decode_contents(
# -> 1180             indent_contents, eventual_encoding, formatter)
#    1181
#    1182         if self.hidden:
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in decode_contents(self, indent_level, eventual_encoding, formatter)
#    1247             elif isinstance(c, Tag):
#    1248                 s.append(c.decode(indent_level, eventual_encoding,
# -> 1249                                   formatter))
#    1250             if text and indent_level and not self.name == 'pre':
#    1251                 text = text.strip()
#
# ... last 2 frames repeated, from the frame below ...
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in decode(self, indent_level, eventual_encoding, formatter)
#    1178             indent_contents = None
#    1179         contents = self.decode_contents(
# -> 1180             indent_contents, eventual_encoding, formatter)
#    1181
#    1182         if self.hidden:
#
# RecursionError: maximum recursion depth exceeded

# %%
#"Slate":slate_links, "Mother Jones":mj_links, "Daily Beast":db_links, "Intercept":intercept_links, "New Republic":nr_links
df = pd.DataFrame({"AmerCons":amercons_links, "BBC":bbc_links, "Breitbart":breitbart_links, "Foxnews":foxnews_links,
                   "Guardian":guardian_links, "Hill":hill_links, "MSNBC":msnbc_links, "National Review":natrev_links,
                   "NY Post":nypost_links, "OANN":oann_links, "Politico":politico_links, "Reason":reason_links,
                   "The Fiscal Times":tft_links, "Wash Post":washpost_links, "Wash Times":washtimes_links})
df

# %%
df = pd.DataFrame({"Hill":hill_links})
df
# Out:
#                              Hill
# bbc.com                        33
# breitbart.com                   8
# foxnews.com                    56
# motherjones.com                 4
# msnbc.com                       9
# nationalreview.com             19
# newrepublic.com                 0
# nypost.com                      1
# oann.com                        0
# politico.com                  156
# reason.com                      0
# slate.com                      11
# theamericanconservative.com     3
# thedailybeast.com              24
# thefiscaltimes.com              0
# theguardian.com                67
# thehill.com                    55
# theintercept.com                0
# washingtonpost.com            430
# washingtontimes.com            18

# %%
df.to_csv('hill.csv')
